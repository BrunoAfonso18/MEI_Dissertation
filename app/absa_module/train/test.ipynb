# %%
import pandas as pd

# %%
df=pd.read_csv('absa_reviews_2014/reviews_pt.csv')

df.columns
# Out:
# Index(['id', 'Sentence', 'Aspect Term', 'polarity', 'from', 'to',
#        'Sentence_pt', 'Aspect Term_pt'],
#       dtype='object')

# %%
df.head()
# Out:
#      id                                           Sentence     Aspect Term  \
# 0  2339  I charge it at night and skip taking the cord ...            cord
# 1  2339  I charge it at night and skip taking the cord ...    battery life
# 2  1316  The tech guy then said the service center does...  service center
# 3  1316  The tech guy then said the service center does...    "sales" team
# 4  1316  The tech guy then said the service center does...        tech guy
#
#    polarity  from   to                                        Sentence_pt  \
# 0   neutral    41   45  Eu carrego à noite e deixo de levar o cabo com...
# 1  positive    74   86  Eu carrego à noite e deixo de levar o cabo com...
# 2  negative    27   41  O técnico então disse que a central de atendim...
# 3  negative   109  121  O técnico então disse que a central de atendim...
# 4   neutral     4   12  O técnico então disse que a central de atendim...
#
#          Aspect Term_pt
# 0                cordão
# ...
